# %% [markdown]
# # Persistant

# %% [markdown]
# ## File

# %% [raw]
# Header: metadata about the contents of the file (file name, size, type, and so on)
# Data: contents of the file as written by the creator or editor
# End of file (EOF): spcial character that indicates the end of the file

# %% [raw]
# 헤더 부분만 읽을 수 있으면 전체 파일을 대부분 읽을 수 있음
# 헤더 부분을 해석하지 못해서 파일을 읽지 못함
#
# 중앙에는 데이터가 있고,
#
# 파일 끝을 나타내는 것은 End of File (EOF)
#
# flat file:
# 텍스트 기반인 파일
# 간단한 헤더가 없는 바이너리 파일
# EOL(End of Line)이 없는 바이너리 파일

# %% [raw]
# %%은 해당 셀 전체에 어떤 조작을 하겠다는 의미
# %%writefile
# 아래 내용들을 moon.txt로 저장하겠다는 의미
# 쥬피터노트북만의 기능

# %% [markdown]
# ###  raw file

# %% [markdown]
# #### open(file, mode='r', buffering=-1,    encoding=None, errors=None, newline=None,  closefd=True, opener=None)

# %%
# %%writefile moon.txt
# asd ffasd
# asdasd
# asdasdasd
# asdasda

# %% [raw]
# 파이썬은 파일 관련 함수가 1개뿐 open()
#
# 파이썬 관점에서 파일의 3요소
# 경로 ~/가 없으면 현재 작업하고 있는 파일 위치와 같은 곳
#
# open()을 하면 파일을 불러들인다는 뜻
# 쉬프트+탭 => mode 옵션
# 작성할 때 사용할 수 있고, 기존에 열려있는 파일을 뒤에 추가할 수 있음

# %%
file = open('moon.txt') # 경로/파일명/확장자

# %%
dir(file)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %% [raw]
# __iter__가 있으면 for에 집어넣을 수 있다
# iterator 또는 generator로 되어있기 때문에 __next__ 함수 사용
#
# __enter__와 __exit__

# %%
next(file)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-10-0f391ff92824> in <module>
# ----> 1 next(file)
#
# StopIteration:

# %% [raw]
# next()은 한줄 한줄을 실행시킨다
# StopIteration 발생
# 왜 이런 구조로 만들었을까?
#
# next()의 좋은 점은 모든 데이터를 메모리 상에 올리지 않고,
# next 하는 애만 올린다
#
# 파이썬 내부에서도 파일을 아주 효율적으로 관리
#
# next()와 똑같은 것은 readline()
# 차이점은 마지막 문장이 오면 에러 발생이 안됨
# try 가지고 에러 발생을 막았음
#
# 에러 체크를 할 수 있다
# 에러 발생하게/ 막을 수 있다 => try

# %%
file.readline()
# Out:
# ''

# %% [raw]
# 모드를 'r' 대신 'w'로 하는 순간부터 한줄씩 한줄씩 파일을 저장할 수 있다

# %%
file = open('sun.txt','w', encoding='utf8')

# %%
file.write('Hello, world!')
file.write('Hello, 문근영!')
# Out:
# 11

# %%
file.close()

# %% [raw]
# 파일을 저장했는데, 어디까지 저장했는지 모름
# 그래서 항상 파일을 열면 마지막에는 닫아줘야함

# %%
file2 = open('sun.txt', encoding='utf8')

# %%
next(file2)
# Out:
# 'Hello, world!Hello, 문근영!'

# %% [raw]
# 문장들이 붙어서 나옴
# 개행문자(줄바꿈문자): \n
#
# close()를 안하면 파일 저장이 안됨
# open - close 짝
# open이 있으면 close 짝이 있어야함
#
# 파이썬에서 짝을 원하는 경우에는
# __enter__와__exit__
#
# __enter__와__exit__가 있으면
# with를 쓸 수 있음
# with 구문에는 as를 쓸 수 있음

# %%
with open('sun.txt', encoding='utf8') as f: # enter, exit
#    print(f.__name__)
    print(f.readline())
# Out:
# Hello, world!Hello, 문근영!

# %% [raw]
# f는 name은 없지만, 실질적으로 f = open('sun.txt')와 같음
#
# with은 enter와 exit가 정의되어 있을 때 사용 가능
# open에는 어떻게 enter와 exit가 정의되어 있을까?
#
# 첫번째 문장이 실행될 때 enter에 정의되어 있는게 실행
# with구문 맨 마지막 문장이 나갈 때 exit가 실행
# exit 실행할 때 안에는 close 있다
#
# 즉, 이 구문을 쓰면 close를 안해도 됨
# 데이터베이스도 연결하면 항상 닫아야함
# 짝을 이루는 형태일 때 with 구문을 쓰면
# 뒤에 것을 안 써도 되게 할 수 있다

# %% [raw]
# as 3가지
# import / except / with

# %% [raw]
# open 안의 exit는 close라는게 정의되어 있다
# with 구문을 사용하면 close가 자동적으로 적용된다
#
# 데이터베이스 배울 때 with 구문을 쓴다면
# with 안에 있는걸 dir 쳐보고 __enter__와 __exit__ 체크해보기

# %%
import sys
sys.stdin.encoding
# Out:
# 'cp1252'

# %%
sys.stdout.encoding
# Out:
# 'UTF-8'

# %% [markdown]
# # with

# %%
with open('sun.txt', 'r', encoding='utf8') as file:
    s = file.read()
    print(s)
# Out:
# Hello, world!Hello, 문근영!

# %% [raw]
# with 해보고 dir 해보고 enter, exit 확인
# with가 있으면 as를 쓴다

# %%
# files = []
# for _ in range(100000):
#     files.append(open('foo.txt', 'w'))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-119-bd12c407fa52> in <module>
#       1 files = []
#       2 for _ in range(100000):
# ----> 3     files.append(open('foo.txt', 'w'))
#
# OSError: [Errno 24] Too many open files: 'foo.txt'

# %% [raw]
# OSError 발생
# 한꺼번에 너무 많은 파일을 열면
# 파이썬 또는 OS가 감당을 못함 -> 중단, 재부팅
#
# close를 한다는 것 = 더 이상 메모리에서 사용하지 않겠다
# 데이터베이스에서 close가 중요한 이유
# 데이터 파일이 아주 클 때 close를 하지 않으면 메모리 문제 발생
# 파이썬은 Garbage Collection을 하기 때문에
# 아주 빨리 많이 실행하지 않으면 자기가 알아서 없애준다
#
# 우리는 빅데이터를 처리하기 때문에
# 파일을 열거나, 데이터베이스를 연결할 때
# 그것을 종료하지 않으면 문제점이 발생될 수 있다.
# 간혹 에러도 없는데, 파일을 실행했더니 컴퓨터가 꺼진다?
# -> close를 생각해볼 것

# %% [markdown]
# # with 예제 plt.xkcd

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %% [raw]
# import antigravity하면 나오는 것이 xkcd

# %%
import antigravity

# %%
with plt.xkcd(): # context manager
    plt.plot([1,2,3,4])

# %% [raw]
# with 구문을 쓰고 xkcd을 하면
# with 안에 있는 부분만 그려지고
# 그 밖은 xkcd 방식으로 안그려짐

# %%
plt.plot([1,2,3,4])

# %%
import inspect

# %%
print(inspect.getsource(plt.xkcd().__exit__))
# Out:
#     def __exit__(self, exc_type, exc_value, exc_tb):
#         self.__fallback()

# %% [raw]
# xkcd에는 이런 구문이 있는데
# fallback() 이라는 예전으로 돌아가라는 명령이
# with 구문이 종료될 때 같이 실행됨
#
# with 이후에는 xkcd 방식으로 안 그려짐
#
# 짝을 이루는 것을 꼭 써야하는 경우
# enter와 exit를 정의하고 그것을
# with 구문으로 사용하면 with 구문 안에만 내용이 적용
#
# with 구문을 context manager 이라고 함
# 이 상황 (context) 안에서만 사용할 수 있다고 해서

# %%
x = plt.xkcd()

# %% [raw]
# 실행하는 순간 xkcd 방식으로 그래프를 그리겠다
# with 구문과 상관없이 무조건 plt 무슨 그림을 그리더라도
# xkcd 방식으로 그려짐

# %%
dir(x)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_orig',
#  '_rc_context__fallback']

# %% [raw]
# __enter__와 __exit__가 있음
# with 구문 사용 가능

# %%
plt.plot([1,2,3,4])

# %% [markdown]
# # with 유명한 라이브러리 PIL

# %% [raw]
# open()은 관례상 보통 with 구문이 있다

# %%
from PIL import Image 
# tensorflow/keras, pytorch 일부 추가 라이브러리 -> 기본적으로 이미지 처리

# %%
import PIL

# %%
dir(PIL)
# Out:
# ['Image',
#  'ImageMode',
#  'TiffTags',
#  'UnidentifiedImageError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_binary',
#  '_imaging',
#  '_plugins',
#  '_raise_version_warning',
#  '_util',
#  'sys',
#  'warnings']

# %%
from PIL import

# %% [raw]
# import 뒤 Tab키를 눌렀을 때 dir에 없는것들이 많이 보임
# dir을 하면 다 보인다고 했음
# 이거를 숨기는 테크닉이 있음

# %%
Image.open('moon.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=596x335 at 0x1F6CEFC5370>

# %%
dir(Image.open('moon.jpg'))
# Out:
# ['_Image__transformer',
#  '__array_interface__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_close_exclusive_fp_after_loading',
#  '_copy',
#  '_crop',
#  '_dump',
#  '_ensure_mutable',
#  '_exclusive_fp',
#  '_exif',
#  '_expand',
#  '_get_safe_box',
#  '_getexif',
#  '_getmp',
#  '_min_frame',
#  '_new',
#  '_open',
#  '_repr_png_',
#  '_seek_check',
#  '_size',
#  'alpha_composite',
#  'app',
#  'applist',
#  'bits',
#  'category',
#  'close',
#  'convert',
#  'copy',
#  'crop',
#  'custom_mimetype',
#  'decoderconfig',
# ...

# %% [raw]
# __enter__와 __exit__가 있으므로 with 구문 사용 가능
#
# with에 enter와 exit가 어떤 기능을 하는가 보기 위해선

# %%
import inspect

# %%
print(inspect.getsource(Image.open('moon.jpg').__exit__))
# Out:
#     def __exit__(self, *args):
#         if hasattr(self, "fp") and getattr(self, "_exclusive_fp", False):
#             if hasattr(self, "_close__fp"):
#                 self._close__fp()
#             if self.fp:
#                 self.fp.close()
#         self.fp = None

# %% [raw]
# exit에서는 close가 정의
# 보통 enter에는 기능이 없다
#
# 간혹 이 구문이 안보이는 것들, 에러가 나는 것들이 있음
# 이유는 C 언어로 만들어졌기 때문이다

# %%
with Image.open('moon.jpg') as f:
    f.rotate(30)
